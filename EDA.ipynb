# %% [markdown]
# <a href="https://colab.research.google.com/github/gowthammarella/THEOREY-OF-COMPUTATION-PROJECT/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/drive/MyDrive/titanic dataset/Titanic_dataset.csv')

df.head()

df.shape
df.info()

df.describe()

df.isnull().sum()

plt.hist(df['Age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

sns.countplot(x='Sex', data=df)
plt.show()

plt.scatter(df['Age'], df['Fare'])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

sns.boxplot(x='Sex', y='Fare', data=df)
plt.show()

sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

(df.isnull().sum() / len(df)) * 100
((df.isnull().sum() / len(df)) * 100).round(2)
(df.isnull().sum() / len(df) * 100).to_frame(name='Missing %')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  AgeGroup     891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB
#              Missing %
# PassengerId   0.000000
# Survived      0.000000
# Pclass        0.000000
# Name          0.000000
# Sex           0.000000
# Age          19.865320
# ...

# %%
# !ls '/content/drive/MyDrive/titanic dataset/'
# Out:
# Titanic_dataset.csv

# %%
# !ls '/content/drive/MyDrive'
# Out:
# 'adharM. Gowtham -1.pdf'	  'III Sem SOCI 2023BTDS083 Gowtham.pdf'
# 'Colab Notebooks'		   IMG20250503154359.jpg
# 'GATE MEGA SHEET NEW.gsheet'	   IMG20250910074713.jpg
# 'Google Sheet for Events.gsheet'   resume_gowtham.pdf
# 'GOWTHAM_cv[1]-1 (2).pdf'	  'titanic dataset'
#  gowtham_CV.pdf			  'Untitled document.gdoc'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
